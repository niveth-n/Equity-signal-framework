# %% [markdown]
# <a href="https://colab.research.google.com/github/niveth-n/Equity-signal-framework/blob/main/notebooks/run_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fresh workspace + run the demo
# %cd /content
# !rm -rf esf
# !git clone https://github.com/niveth-n/equity-signal-framework.git esf
# %cd esf
# !python -m src.backtest --config evidence/backtest_config.yaml

from IPython.display import Image, display
display(Image("results/plots/equity_curve.png"))
display(Image("results/plots/confusion_matrix.png"))
print(open("results/oos_metrics.csv").read())
# Out:
# /content
# Cloning into 'esf'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 96 (delta 34), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (96/96), 127.01 KiB | 3.34 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/esf
#
# OOS metrics
#  start_date   end_date  accuracy  precision  recall    f1  sharpe  max_dd  strat_return  buyhold_return  turnover
# 2025-07-01 2025-07-31      50.0      42.66   52.14 46.92    -2.1    2.28         -1.67           -0.94      0.25
# start_date,end_date,accuracy,precision,recall,f1,sharpe,max_dd,strat_return,buyhold_return,turnover
# 2025-07-01,2025-07-31,50.0,42.66,52.14,46.92,-2.1,2.28,-1.67,-0.94,0.25
